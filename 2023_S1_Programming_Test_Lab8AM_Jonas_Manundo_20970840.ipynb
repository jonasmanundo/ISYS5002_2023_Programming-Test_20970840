# %% [markdown]
# <a href="https://colab.research.google.com/github/jonasmanundo/ISYS5002_2023_Programming-Test_20970840/blob/main/2023_S1_Programming_Test_Lab8AM_Jonas_Manundo_20970840.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Instructions - Read Carefully**
#
# * This is an in-class **restricted-book** assessment.
# * Personal devices, including laptops, smartphones, translators, AI tools are **NOT** allowed
# * Acces to other websites or materials are **NOT** allowed.
# * You are only **allowed** to refer to **materials in your own private GitHub repository**.
# * This is an individual assessment, so all work must be your own.
# * You may not communicate with anyone other than the instructor in regard to this assignment.
# * Please contact the instructor if you have any questions regarding any of the problems on the assignment.
#
#
# Before you start,
# * Download the attached .ipynb notebook and rename it to *2023_S1_Programming_Test_[name]_[studentID]*
# * Save the renamed notebook to your private GitHub repository.
# * Copy and paste the repository/notebook link in the ANSWER textbox on Blackboard.
#
# Save your notebook to your private GitHub repository
# * at the beginning of the test
# * middle of the test
# * end of the test

# %% [markdown]
# # Problem Statement: Weekly Sales Reporting
#
# BeeGeez Retail is a store that sells various types of electronic gadgets. The store manager wants to analyse the weekly sales revenue generated by a particular product to make informed decisions regarding pricing and marketing strategies. The product is a new smartphone model that the store recently started selling.
#
# To accomplish this task, the store manager has asked you to develop a Python program that can calculate and visualise the weekly sales revenue for the product. The program should prompt the user to enter the name of the product and the sales data for each week, including the price and quantity sold.
#
# The program should be able to handle any number of weeks entered by the user and generate the weekly revenue data for each week. The program should also write the weekly revenue data to a CSV file and generate a graph to visually represent the sales revenue.
#
# Based on the sales data analysis, the store manager will be able to make informed decisions regarding pricing and marketing strategies to maximise the revenue generated by the product.
#
# **Task:**
#
# Following the **six-steps problem-solving methodology**, **design and implement** the solution following good programming practices, such as modularising code, validating inputs, handling errors properly, and adhering to the PEP8 style guide.
#
# Adhering to PEP8 standards:
# * programming style naming conventions used in the PEP8, which include:
#   * Meaningful names for projects, variables, methods, and controls.
#   * Correct capitalisation of variables and methods
# * Appropriate use of comments
# * Reference any relevant forums, websites, and videos that you used.
# * Use of space and indentation to the program is easy to read.

# %% [markdown]
# PROBLEM
#
# Calculate and visualize weekly sales revenue of new smartphone model
#
# REQUIREMENTS
#
# - calculate weekly sales revenue
# - visualize through graph
# - prompt user to enter name of product
# - prompt user to enter sales data per week
# - sales data includes price and quantity sold
# - can handle any number of weeks entered
# - generate weekly revenue data
# - can write and save to csv file
#
# INPUT /OUTPUT
#
# INPUT
#
# - enter name of product
# - enter week number
# - enter price
# - enter quantity sold
#
# OUTPUT
#
# - sales = price * quantity
# - sales for the week
# - save revenue for the week to csv file rev.csv
# - create graph for the sales per week
#
# PROBLEM SAMPLE
#
# week 1 sales for smartphone
# price = $150
# units sold = 100
# week 1 sales = 150 * 100 = 1,500
#
#
# ALGORITHM
#
# # enter product name
#
# # enter week number
#
# # enter price
#
# # enter units sold
#
# # compute total sales for the week
#
# TESTING

# %%
while True:
  try:
    # enter product name
    name = input("Please enter Product Name: ")
    # enter week number
    week = input("Please enter Week Number: ")
    # enter price
    distance = float(input("Please enter distance: "))
    if distance < 0:
       raise ValueError("Input must not be negative")
    # get user input for time
    time = float(input("Please enter time: "))
    if time < 0:
       raise ValueError("Input must not be negative")
    break # use break to stop loop
  except ValueError:
    print("Invalid input for distance/time. Please Enter a numeric value")
    # pass the date, distance, time values to function speed_calc
  # receive/capture the return values from the function
  #distance_conv, speed = speed_calc(distance_conv, speed)

distance_km = distance * 1.60934

# calculate the speed in kilometers per hour
time_hours = time / 60
speed_kph = distance_km / time_hours

    # print out the data nicely formatted
print(f'\n=== {name}s run on {date} ===')
print(f"distance: {distance_km:9} \ntime: {(time_hours):5} \nspeed: {speed_kph:13}")

# %% [markdown]
# # ANSWER
